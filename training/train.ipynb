# %%
import os

os.chdir('./drive/MyDrive/MaskGA_Net')

# %%
# !pip install -r requirements.txt

# %%
# !python supervision_tools.py --dataset TNBC --random_shift 5
# Out:
# Generating Sp supervision...
# 100% 50/50 [01:10<00:00,  1.41s/it]
# Done!

# %%
# !python train.py --dataset TNBC --model_name 000 --epochs 1 --k_fold 3 --random_shift 5
# Out:
# You are using CL, but it looks like you didnt finish to train a network with stage=0
# Program will train a newtork on previous stages with the same setting first. Then use CL
# If you wish to use different settings, see train.py --help or README.md
#
# Framework will continually run from withou CL to with CL...
#
# Framework will run without CL [stage=0]
#
# Initialising logs...
# Training for 1 epochs
# Dataset: TNBC
# Framework: SAC
# If use CL: False, Iteration times: 0
#
# Initialising training loss...
#
# Initialising evaluation metrics...
#
# Network, log files, results are saved in ./checkpoints/TNBC/stage0/000-SAC-cs0-NNone-Sp-r5
#
# Display configurations:
# {
#   "Dataset": {
#     "dataset": "TNBC",
#     "k_fold": 3,
#     "random_shift": 5,
#     "mode_label": "Sp",
#     "cut_size": 0,
#     "data_norm": "unit",
#     "seed": 12,
#     "color_norm": null
#   },
#   "Framework": {
#     "stage": 0,
#     "model_name": "000-SAC-cs0-NNone-Sp-r5",
# ...
