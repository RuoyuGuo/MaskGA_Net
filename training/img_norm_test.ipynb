# %%
import os
os.chdir('./drive/MyDrive/Medical_Image_Analysis')

# %%
# !pip install -r requirements.txt

# %%
# !python norm.py --dataset TNBC
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/adagrad.py:143: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2022-01-05 02:03:06.192773: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# normalize slide 10_3.png
# normalize slide 04_4.png
# normalize slide 05_3.png
# normalize slide 03_3.png
# normalize slide 03_4.png
# normalize slide 02_1.png
# normalize slide 07_1.png
# normalize slide 09_5.png
# normalize slide 08_3.png
# normalize slide 08_1.png
# normalize slide 07_3.png
# normalize slide 07_2.png
# normalize slide 10_2.png
# normalize slide 06_3.png
# normalize slide 02_2.png
# normalize slide 01_1.png
# normalize slide 03_2.png
# ...
